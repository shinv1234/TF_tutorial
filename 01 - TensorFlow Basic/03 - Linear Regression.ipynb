# %%
import tensorflow as tf

# %%
x_data = [1, 2, 3]
y_data = [1, 2, 3]

# %%
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
print(W)
print(b)
# Out:
# <tf.Variable 'Variable:0' shape=(1,) dtype=float32_ref>
# <tf.Variable 'Variable_1:0' shape=(1,) dtype=float32_ref>

# %%
# name: 나중에 텐서보드등으로 값의 변화를 추적하거나 살펴보기 쉽게 하기 위해 이름을 붙여줍니다.
X = tf.placeholder(tf.float32, name="X")
Y = tf.placeholder(tf.float32, name="Y")
print(X)
print(Y)
# Out:
# Tensor("X:0", dtype=float32)
# Tensor("Y:0", dtype=float32)

# %%
hypothesis = W * X + b # 행렬이 아니므로 tf.matmul 사용하지 않음

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y)) # 손실 함수: mean(h - Y)^2
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1) # GD 최적화 학습률 0.1
train_op = optimizer.minimize(cost) # 손실 함수에 GD 최적화를 적용

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(100):
        _, cost_val =  sess.run([train_op, cost], feed_dict={X: x_data, Y: y_data})
        print(step, cost_val, sess.run(W), sess.run(b))
        
    print("\n=== Test ===")
    print("X: 5, Y:", sess.run(hypothesis, feed_dict={X: 5}))
    print("X: 2.5, Y", sess.run(hypothesis, feed_dict={X: 2.5}))
# Out:
# 0 6.39971 [ 1.19863451] [-0.16013139]
# 1 0.082538 [ 1.07729495] [-0.20755892]
# 2 0.00678873 [ 1.08817649] [-0.19696513]
# 3 0.00560825 [ 1.08466446] [-0.19284269]
# 4 0.00533162 [ 1.08278131] [-0.18813995]
# 5 0.00507823 [ 1.08077466] [-0.18362449]
# 6 0.00483701 [ 1.07883477] [-0.17920944]
# 7 0.00460725 [ 1.07693946] [-0.17490146]
# 8 0.0043884 [ 1.07508993] [-0.17069693]
# 9 0.00417995 [ 1.07328475] [-0.16659351]
# 10 0.0039814 [ 1.07152307] [-0.1625887]
# 11 0.00379228 [ 1.06980371] [-0.15868019]
# 12 0.00361214 [ 1.06812561] [-0.15486564]
# 13 0.00344055 [ 1.06648803] [-0.15114275]
# 14 0.00327713 [ 1.06488967] [-0.14750941]
# 15 0.00312147 [ 1.0633297] [-0.1439634]
# 16 0.0029732 [ 1.06180727] [-0.1405026]
# 17 0.00283196 [ 1.06032157] [-0.137125]
# 18 0.00269745 [ 1.05887139] [-0.13382863]
# 19 0.00256932 [ 1.05745614] [-0.13061146]
# 20 0.00244727 [ 1.05607498] [-0.12747164]
# 21 0.00233102 [ 1.05472708] [-0.12440729]
# 22 0.0022203 [ 1.05341136] [-0.12141667]
# ...
